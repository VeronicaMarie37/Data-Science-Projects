# %%
import seaborn as sns
import matplotlib.pyplot as ply
import pandas as pd

# %%
house = pd.read_csv("house.csv")

# %%
house.head()
# Out:
#    number_of_rooms  floor  area   latitude  longitude   price
# 0                1      1  58.0  38.585834  68.793715  330000
# 1                1     14  68.0  38.522254  68.749918  340000
# 2                3      8  50.0        NaN        NaN  700000
# 3                3     14  84.0  38.520835  68.747908  700000
# 4                3      3  83.0  38.564374  68.739419  415000

# %%
house.dropna(inplace=True)

# %%
house.isnull().sum()
# Out:
# number_of_rooms    0
# floor              0
# area               0
# latitude           0
# longitude          0
# price              0
# dtype: int64

# %%
sns.scatterplot(data = house, x = "area", y = "price", hue= "floor")
ply.title("price vs area")
ply.show()

# %%
sns.scatterplot(data = house, x = "number_of_rooms", y = "floor",)
ply.show()

# %%
sns.lineplot(data = house, x="number_of_rooms", y="floor")
# Out:
# <Axes: xlabel='number_of_rooms', ylabel='floor'>

# %%
sns.lineplot(data = house, x="area", y="price", hue= "floor")
ply.title("area vs price")
plt.show()
# Out:
# Text(0.5, 1.0, 'area vs price')

# %%
sns.barplot(data= house, x="floor", y="price")
# Out:
# <Axes: xlabel='floor', ylabel='price'>

# %%
sns.histplot(house["area"], kde=True)
# Out:
# <Axes: xlabel='area', ylabel='Count'>

# %%
sns.boxplot(data=house, x="number_of_rooms", y="area")
# Out:
# <Axes: xlabel='number_of_rooms', ylabel='area'>

# %%
sns.violinplot(data=house, x="number_of_rooms", y="floor")
# Out:
# <Axes: xlabel='number_of_rooms', ylabel='floor'>

# %%
sns.heatmap(house.corr(), annot=True, cmap="Purples")
# Out:
# <Axes: >

# %%
sns.pairplot(data=house, hue="number_of_rooms")

# %%
sns.pairplot(data=house)

# %%
sns.pairplot(data=house, hue="number_of_rooms", kind= "kde")
